# %% [markdown]
# <a href="https://colab.research.google.com/github/hiiamnikhil/IE434_Project/blob/main/IE_434_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# This is the file for the project. The link to the GitHUb Repo is as follows. It has the README.md and License file
#
# https://github.com/hiiamnikhil/IE434_Project/tree/988e1824083505fdd82463318a1048b0bb183ad1

# %%
from google.colab import drive

# %%
import pandas as pd
import seaborn as sns
import matplotlib as mlt

# %%
drive.mount('/content/drive')
datadir = "/content/drive/My Drive/IE434_ProjectGroup7/Data_JC_2022"
import os
os.chdir(datadir)
filepath = os.path.join(datadir, "202201-citibike-tripdata.csv")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
master=pd.DataFrame()
for i, file_name in enumerate(os.listdir()):
  if file_name.endswith(".csv"):
    temp = pd.read_csv(file_name)
    master = pd.concat([master, temp], axis=0, ignore_index=True)

# %%
master
# Out:
#                  ride_id  rideable_type           started_at  \
# 0       4999883C92EACCB0   classic_bike  2022-09-01 21:05:47
# 1       CC87E6815E075F6F   classic_bike  2022-09-10 18:09:26
# 2       B54E7FDDF4C251E6   classic_bike  2022-09-26 21:46:24
# 3       A19A3DC77A98F6C2   classic_bike  2022-09-08 20:11:41
# 4       3530E340A0B0E93F   classic_bike  2022-09-08 17:05:38
# ...                  ...            ...                  ...
# 895480  D438F1622839AC50   classic_bike  2022-12-06 15:43:38
# 895481  747A63A8E782D171  electric_bike  2022-12-08 08:17:51
# 895482  AE090858CFDE6E82  electric_bike  2022-12-23 14:10:07
# 895483  B3CC8E70AF4E259C   classic_bike  2022-12-02 04:43:25
# 895484  176B601F21327350   classic_bike  2022-12-30 14:50:17
#
#                    ended_at                      start_station_name  \
# 0       2022-09-01 21:08:07                            Jersey & 3rd
# 1       2022-09-10 18:11:48                            Jersey & 3rd
# ...

# %%
master.columns
# Out:
# Index(['ride_id', 'rideable_type', 'started_at', 'ended_at',
#        'start_station_name', 'start_station_id', 'end_station_name',
#        'end_station_id', 'start_lat', 'start_lng', 'end_lat', 'end_lng',
#        'member_casual'],
#       dtype='object')

# %%
master['ended_at']=pd.to_datetime(master['ended_at'])
master['started_at']=pd.to_datetime(master['started_at'])

# %%
os.chdir("/content/drive/My Drive/IE434_ProjectGroup7/")
master.to_pickle("Bikedata_2022.pkl")
